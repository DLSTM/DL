# %%
# !pip install kaggle tensorflow numpy pandas matplotlib seaborn

https://drive.google.com/file/d/1Y4ZffAgvxC9GnYLWsXVcUFDQQm8H3uAb/view?usp=sharing

# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Download Plant Disease Dataset (PlantVillage)
# !kaggle datasets download -d emmarex/plantdisease
# !unzip -q plantdisease.zip -d plant_disease_data

# Verify dataset extraction
import os
print("Extracted Files:", os.listdir("plant_disease_data"))

# Import necessary libraries
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define dataset path (within Colab environment)
data_dir = 'plant_disease_data/'


# Data Preprocessing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)

# Define CNN Model
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(len(train_generator.class_indices), activation='softmax')
])

# Compile the Model
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Train the Model
epochs = 10
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs
)

# Evaluate Model
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Save Model (within Colab environment)
model.save('plant_disease_model.h5')
print('Model saved as plant_disease_model.h5')
# Out:
# Collecting kaggle
#   Downloading kaggle-1.7.4.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tensorflow in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (2.17.0)
# Requirement already satisfied: numpy in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (1.5.3)
# Requirement already satisfied: matplotlib in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (3.9.0)
# Requirement already satisfied: seaborn in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (0.13.2)
# Collecting bleach (from kaggle)
#   Downloading bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: certifi>=14.05.14 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: charset-normalizer in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (3.3.2)
# Requirement already satisfied: idna in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (3.6)
# Requirement already satisfied: protobuf in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (4.25.6)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (72.1.0)
# Requirement already satisfied: six>=1.10 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: text-unidecode in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (4.66.2)
# Requirement already satisfied: urllib3>=1.15.1 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (2.3.0)
# Requirement already satisfied: webencodings in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from kaggle) (0.5.1)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorflow) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (24.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (2.17.0)
# Requirement already satisfied: keras>=3.2.0 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow) (0.31.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: colorama in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tqdm->kaggle) (0.4.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.12.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (2.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\anujt_3nxzaxy\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow) (0.1.2)
# Downloading kaggle-1.7.4.2-py3-none-any.whl (173 kB)
# Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
# Installing collected packages: bleach, kaggle
# Successfully installed bleach-6.2.0 kaggle-1.7.4.2
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 get_ipython().system('pip install kaggle tensorflow numpy pandas matplotlib seaborn')
#       3 # Upload kaggle.json API Key
# ----> 4 from google.colab import files
#       5 import os
#       6 files.upload()
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
import os


# Import necessary libraries
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define dataset path (within Colab environment)
data_dir = 'plantdisease/'

import os
print("Extracted Files:", os.listdir("plantdisease"))



# Data Preprocessing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical',
    subset='validation'
)

# Define CNN Model
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(len(train_generator.class_indices), activation='softmax')
])

# Compile the Model
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Train the Model
epochs = 10
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs
)

# Evaluate Model
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Save Model (within Colab environment)
model.save('plant_disease_model.h5')
print('Model saved as plant_disease_model.h5')
# Out:
# Extracted Files: ['plantdisease']
# Found 3960 images belonging to 1 classes.
# Found 990 images belonging to 1 classes.
# Epoch 1/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 115s 914ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 2/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 75s 598ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 3/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 54s 436ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 4/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 56s 451ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 5/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 55s 444ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 6/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 51s 414ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 7/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 54s 434ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 8/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 53s 429ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 9/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 60s 484ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 1.0000 - val_loss: 0.0000e+00
# Epoch 10/10
# 102/124 ━━━━━━━━━━━━━━━━━━━━ 9s 436ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# Cell In[2], line 71
#      69 # Train the Model
#      70 epochs = 10
# ---> 71 history = model.fit(
#      72     train_generator,
#      73     validation_data=val_generator,
#      74     epochs=epochs
#      75 )
#      77 # Evaluate Model
#      78 plt.plot(history.history['accuracy'], label='Training Accuracy')
#
# File c:\Users\anujt_3nxzaxy\anaconda3\lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File c:\Users\anujt_3nxzaxy\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# UnknownError: Graph execution error:
#
# Detected at node PyFunc defined at (most recent call last):
# <stack traces unavailable>
# FileNotFoundError: [Errno 2] No such file or directory: 'plantdisease/plantdisease\\PlantVillage\\Pepper__bell___healthy\\90e840e0-3b8c-4100-8340-ef0ed67e5972___JR_HL 8367.JPG'
# Traceback (most recent call last):
#
#   File "c:\Users\anujt_3nxzaxy\anaconda3\lib\site-packages\tensorflow\python\ops\script_ops.py", line 270, in __call__
#     ret = func(*args)
#
#   File "c:\Users\anujt_3nxzaxy\anaconda3\lib\site-packages\tensorflow\python\autograph\impl\api.py", line 643, in wrapper
#     return func(*args, **kwargs)
#
#   File "c:\Users\anujt_3nxzaxy\anaconda3\lib\site-packages\tensorflow\python\data\ops\from_generator_op.py", line 198, in generator_py_func
#     values = next(generator_state.get_iterator(iterator_id))
#
#   File "c:\Users\anujt_3nxzaxy\anaconda3\lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py", line 247, in _finite_generator
#     yield self.py_dataset[i]
#
#   File "c:\Users\anujt_3nxzaxy\anaconda3\lib\site-packages\keras\src\legacy\preprocessing\image.py", line 68, in __getitem__
#     return self._get_batches_of_transformed_samples(index_array)
#
#   File "c:\Users\anujt_3nxzaxy\anaconda3\lib\site-packages\keras\src\legacy\preprocessing\image.py", line 313, in _get_batches_of_transformed_samples
#     img = image_utils.load_img(
#
#   File "c:\Users\anujt_3nxzaxy\anaconda3\lib\site-packages\keras\src\utils\image_utils.py", line 235, in load_img
#     with open(path, "rb") as f:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'plantdisease/plantdisease\\PlantVillage\\Pepper__bell___healthy\\90e840e0-3b8c-4100-8340-ef0ed67e5972___JR_HL 8367.JPG'
#
#
# 	 [[{{node PyFunc}}]]
# 	 [[IteratorGetNext]] [Op:__inference_one_step_on_iterator_7999]

# %%
import os
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Set the path to your two-class dataset
data_dir = r'D:\DLPROJECTS\DL2\DL\DL1-main\Allassignments\PepperBell2Class'

# Check the folders (should show the two class folders)
print("Class folders:", os.listdir(data_dir))

# Data Preprocessing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

train_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

val_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='categorical',
    subset='validation',
    shuffle=True
)

# Print detected classes
print("Detected classes:", train_generator.class_indices)

# Define CNN Model
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(2, activation='softmax')  # 2 classes
])

# Compile the Model
model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# Train the Model
epochs = 10
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs
)

# Evaluate Model
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Save Model
model.save('plant_disease_model.h5')
print('Model saved as plant_disease_model.h5')
# Out:
# Class folders: ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy']
# Found 1981 images belonging to 2 classes.
# Found 494 images belonging to 2 classes.
# Detected classes: {'Pepper__bell___Bacterial_spot': 0, 'Pepper__bell___healthy': 1}
# Epoch 1/10
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 29s 431ms/step - accuracy: 0.6800 - loss: 0.7391 - val_accuracy: 0.8198 - val_loss: 0.4240
# Epoch 2/10
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 405ms/step - accuracy: 0.8811 - loss: 0.3328 - val_accuracy: 0.9130 - val_loss: 0.2436
# Epoch 3/10
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 24s 393ms/step - accuracy: 0.9089 - loss: 0.2571 - val_accuracy: 0.9413 - val_loss: 0.1908
# Epoch 4/10
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 402ms/step - accuracy: 0.8666 - loss: 0.3396 - val_accuracy: 0.9474 - val_loss: 0.1882
# Epoch 5/10
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 406ms/step - accuracy: 0.9568 - loss: 0.1217 - val_accuracy: 0.9271 - val_loss: 0.2084
# Epoch 6/10
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 406ms/step - accuracy: 0.9503 - loss: 0.1489 - val_accuracy: 0.9555 - val_loss: 0.1320
# Epoch 7/10
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 407ms/step - accuracy: 0.9511 - loss: 0.1387 - val_accuracy: 0.9595 - val_loss: 0.1482
# Epoch 8/10
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 24s 382ms/step - accuracy: 0.9679 - loss: 0.1170 - val_accuracy: 0.9717 - val_loss: 0.0898
# Epoch 9/10
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 24s 390ms/step - accuracy: 0.9891 - loss: 0.0407 - val_accuracy: 0.9696 - val_loss: 0.1115
# Epoch 10/10
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 24s 388ms/step - accuracy: 0.9845 - loss: 0.0485 - val_accuracy: 0.9717 - val_loss: 0.0938
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved as plant_disease_model.h5

# %%
import matplotlib.pyplot as plt
import numpy as np

# Get a batch of images and labels from the validation generator
images, labels = next(val_generator)

# Predict classes for this batch
preds = model.predict(images)
pred_classes = np.argmax(preds, axis=1)
true_classes = np.argmax(labels, axis=1)

# Get class labels mapping
class_labels = list(train_generator.class_indices.keys())

# Plot first 8 images with their predicted and true labels
plt.figure(figsize=(16, 8))
for i in range(8):
    plt.subplot(2, 4, i+1)
    plt.imshow(images[i])
    plt.axis('off')
    plt.title(f"Pred: {class_labels[pred_classes[i]]}\nTrue: {class_labels[true_classes[i]]}")
plt.tight_layout()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
